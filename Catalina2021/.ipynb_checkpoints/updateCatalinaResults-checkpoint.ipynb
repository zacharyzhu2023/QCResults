# %%
import pandas as pd
import numpy as np
import datetime as dt
import re
import os
import aurora_data_api
from dateutil import parser

# %%
nameMap = {
    'MEGAN': "Megan Schacht-bonneau",
    'Megan': "Megan Schacht-bonneau",
    "JORDYS": "Jordys Placido",
    "Jordys": "Jordys Placido",
    "NIKKY": "Nikky Voeuth",
    "Nikky": "Nikky Voeuth"
}

def getDate(inp):
    dateVal = re.findall('[0-9][0-9]?/..?/2?0?21', inp)[0]
    formatted = parser.parse(dateVal).strftime('%Y-%m-%d')
    return formatted

# Assume that 
def getFailureType(inp):
    if inp[0] == 'W':
        return inp[:6]
    else:
        return 'none'
    
def getBatchNumber(inp):
    mostRecentBatch = inp.iloc[0]
    for i in range(len(inp)):
        val = inp.iloc[i]
        if type(val) == str:
            mostRecentBatch = val.split(' ')[1]
        inp.iloc[i] = mostRecentBatch
    return inp

def getTester(inp):
    return nameMap.get(inp, inp)

# Execute a SQL query: helper method to be used by insertEntry
def execute(q):
    try:
        db = aurora_data_api.connect(aurora_cluster_arn = r_ARN, secret_arn=s_ARN, database=dbName)
        c = db.cursor()
        c.execute(q) # Execute the query
        db.commit()
        return c.fetchall() # Display the output of said query
    except Exception as e: # Error occurred during execute
        print('Error with execute:', e)
    
        return (float('inf'), e)
    
def insertEntry(sn, bn, date, tst, ft, fail, msg, dt, fw):
    try:
        q = ''' Insert into QAResults values ('%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s')''' % (sn, bn, date, tst, ft, fail, msg, dt, fw)
        return execute(q)
    except Exception as e:
        print('serialNum', sn)
        print('Issue with insert entry:', e)
    
# Read the path in--get a table formatted to more easily insert entries
def readPath(path, deviceType):
    df = pd.read_excel(path)
    df = df.dropna(subset = ['Unnamed: 1'])
    df = df[df['Unnamed: 0'] != 'BATCH']
    df = df.drop(columns = ['Unnamed: 5'])
    df.columns = ['BatchNumber', 'SerialNumber', 'FunctionalTest', 'LogMessage', 'Tester']
    df['BatchNumber'] = getBatchNumber(df['BatchNumber'])
    df = df[df['FunctionalTest'] != 'RESULT']
    df['Tester'] = df['Tester'].apply(getTester)
#     display(df)
    df['Date'] = df['LogMessage'].apply(getDate)
    df['FailureType'] = df['LogMessage'].apply(getFailureType)
    df['DeviceType'] = deviceType
    
    return df

paths = []
directories = [d for d in os.listdir('.') if d[-1] == '1']
allFiles = []
for d in directories:
    currPaths = os.listdir('./' + d)
    allFiles = allFiles + [d + "/" + p for p in currPaths if '$' not in p]
display(allFiles)
# Out:
# ['April 2021/Catalina QC Test 04.11 04.17 2021.xlsx',
#  'April 2021/Catalina QC Test 04.18 04.24 2021.xlsx',
#  'April 2021/Catalina QC Test 04.04 04.10 2021.xlsx',
#  'April 2021/Catalina QC Test 04.25 05.01 2021.xlsx',
#  'February 2021/Catalina QC Test 01.31 02.06 2021.xlsx',
#  'February 2021/Catalina QC Test 02.14 02.20 2021.xlsx',
#  'February 2021/Catalina QC Test 02.21 02.27 2021.xlsx',
#  'February 2021/Catalina QC Test 02.07 02.13 2021.xlsx',
#  'June 2021/Catalina QC Test 06.06 to 06.12 2021.xlsx',
#  'June 2021/Catalina QC Test 06.20 to 06.26 2021.xlsx',
#  'June 2021/Catalina QC Test 06.27 to 07.03 2021.xlsx',
#  'June 2021/Catalina QC Test 06.013 to 06.19 2021.xlsx',
#  'July 2021/Catalina QC Test 07.18 to 07.24 2021.xlsx',
#  'July 2021/Catalina QC Test 07.11 to 07.17 2021.xlsx',
#  'July 2021/Catalina QC Test 07.04 to 07.10 2021.xlsx',
#  'January 2021/Catalina QC Test 01.03 01.09 2021 Restored January 08, 2021 at 08.06.49.108 AM PST.xlsx',
#  'January 2021/Catalina QC Test 01.10 01.16 2021.xlsx',
#  'January 2021/Catalina QC Test 01.24 01.30 2021.xlsx',
#  'January 2021/Catalina QC Test 01.17 01.23 2021.xlsx',
#  'May 2021/Catalina QC Test 05.09 05.15 2021.xlsx',
#  'May 2021/Catalina QC Test 05.03 05.08 2021.xlsx',
#  'May 2021/.ipynb_checkpoints',
#  'May 2021/Catalina QC Test 05.30 06.05 2021.xlsx',
#  'May 2021/Catalina QC Test 05.23 05.29 2021.xlsx',
#  'May 2021/ResultsUpdate-cat_may_2021.ipynb',
#  'May 2021/Catalina QC Test 05.16 05.22 2021.xlsx',
#  'March 2021/Catalina QC Test 03.28 04.03 2021.xlsx',
#  'March 2021/Catalina QC Test 02.28 03.06 2021.xlsx',
#  'March 2021/Catalina QC Test 03.07 03.13 2021.xlsx',
#  'March 2021/Catalina QC Test 03.21 03.27 2021.xlsx',
#  'March 2021/Catalina QC Test 03.14 03.20 2021.xlsx']

# %%
port = 3306
user = 'admin'
password = 'password'

host = 'dashboarddb.cluster-cyvmmsfjcmrl.us-east-1.rds.amazonaws.com'
dbName = 'db'
r_ARN = 'arn:aws:rds:us-east-1:319481862133:cluster:dashboarddb'
s_ARN = 'arn:aws:secretsmanager:us-east-1:319481862133:secret:dashboardDBKey-6XBatB'
def insertTable(res):
    for i in range(len(res)):
        row = res.iloc[i]
        bn = row['BatchNumber']
        sn = row['SerialNumber']
        tst = row['Tester']
        msg = row['LogMessage']
        ft = row['FunctionalTest']
        fail = row['FailureType']
        date = row['Date']
        dt = row['DeviceType']
        fw = '10.42'
        insertEntry(sn, bn, date, tst, ft, fail, msg, dt, fw)
    print('success!')

# %%
device = 'Catalina' # Get the type of device

# April Entries are all inserted
res1 = readPath(allFiles[0], 'Catalina') # Read the information from that path
res1.head()
res2 = readPath(allFiles[1], device)
res2.head()
res3 = readPath(allFiles[2], device)
res3.head()


# Tables for Catalina: March
res4 = readPath(allFiles[-5], device)
display(res4.head())
res5 = readPath(allFiles[-4], device)
display(res5.head())
res6 = readPath(allFiles[-3], device)
display(res6.head())
res7 = readPath(allFiles[-2], device) # Missing some dates--pretend they're all completed on 03/23/2021
display(res7.head())
res8 = readPath(allFiles[-1], device)
display(res8.head())

''' Still need to deal with Jan, Feb, Jun, Jul'''
# Out:
#        BatchNumber         SerialNumber FunctionalTest  \
# 1  UK20200928-A10D  G8T1-GJ00-0301-1LS2           PASS
# 2  UK20200928-A10D  G8T1-GJ00-0301-1LUW           PASS
# 3  UK20200928-A10D  G8T1-GJ00-0301-1LUD           PASS
# 4  UK20200928-A10D  G8T1-GJ00-0301-1LT7           PASS
# 5  UK20200928-A10D  G8T1-GJ00-0301-1LT2           PASS
#
#                                           LogMessage                 Tester  \
# 1  WHW-70 (SERIAL STICKER IN WRONG SPOT)//COMPLET...  Megan Schacht-bonneau
# 2                    WHW-70//COMPLETED ON 03/30/2021  Megan Schacht-bonneau
# 3                    WHW-70//COMPLETED ON 03/30/2021  Megan Schacht-bonneau
# 4                    WHW-70//COMPLETED ON 03/30/2021  Megan Schacht-bonneau
# 5                    WHW-70//COMPLETED ON 03/30/2021  Megan Schacht-bonneau
#
#          Date FailureType DeviceType
# 1  2021-03-30      WHW-70   Catalina
# 2  2021-03-30      WHW-70   Catalina
# 3  2021-03-30      WHW-70   Catalina
# 4  2021-03-30      WHW-70   Catalina
# 5  2021-03-30      WHW-70   Catalina
#       BatchNumber         SerialNumber FunctionalTest  \
# 1  EU20200928-A5N  G8T1-GJ00-0301-207F           PASS
# 2  EU20200928-A5N  G8T1-GJ00-0301-206N           PASS
# 3  EU20200928-A5N  G8T1-GJ00-0301-206X           PASS
# 4  EU20200928-A5N  G8T1-GJ00-0301-2087           PASS
# 5  EU20200928-A5N  G8T1-GJ00-0301-207G           PASS
#
#                 LogMessage                 Tester        Date FailureType  \
# 1  COMPLETED ON 03/01/2021  Megan Schacht-bonneau  2021-03-01        none
# 2  COMPLETED ON 03/01/2021  Megan Schacht-bonneau  2021-03-01        none
# 3  COMPLETED ON 03/01/2021  Megan Schacht-bonneau  2021-03-01        none
# 4  COMPLETED ON 03/01/2021  Megan Schacht-bonneau  2021-03-01        none
# 5  COMPLETED ON 03/01/2021  Megan Schacht-bonneau  2021-03-01        none
#
#   DeviceType
# 1   Catalina
# 2   Catalina
# 3   Catalina
# 4   Catalina
# 5   Catalina
#        BatchNumber         SerialNumber FunctionalTest  \
# 1  UK20201207-A19N  G8T1-GJ00-0311-CJT2           PASS
# 2  UK20201207-A19N  G8T1-GJ00-0311-CJST           PASS
# 3  UK20201207-A19N  G8T1-GJ00-0311-CJSU           PASS
# 4  UK20201207-A19N  G8T1-GJ00-0311-CJSV           PASS
# 5  UK20201207-A19N  G8T1-GJ00-0311-CJT1           PASS
#
#                                           LogMessage                 Tester  \
# 1  WHW-70 (SERIAL STICKER IN WRONG SPOT)//COMPLET...  Megan Schacht-bonneau
# 2                    WHW-70//COMPLETED ON 03/08/2021  Megan Schacht-bonneau
# 3                    WHW-70//COMPLETED ON 03/08/2021  Megan Schacht-bonneau
# 4                    WHW-70//COMPLETED ON 03/08/2021  Megan Schacht-bonneau
# 5                    WHW-70//COMPLETED ON 03/08/2021  Megan Schacht-bonneau
#
#          Date FailureType DeviceType
# 1  2021-03-08      WHW-70   Catalina
# 2  2021-03-08      WHW-70   Catalina
# 3  2021-03-08      WHW-70   Catalina
# 4  2021-03-08      WHW-70   Catalina
# 5  2021-03-08      WHW-70   Catalina
#       BatchNumber         SerialNumber FunctionalTest  \
# 1  NA20210222-A1D  G8T1-GH00-1046-11RQ           PASS
# 2  NA20210222-A1D  G8T1-GH00-1046-11S3           PASS
# 3  NA20210222-A1D  G8T1-GH00-1046-11T7           PASS
# 4  NA20210222-A1D  G8T1-GH00-1046-11SL           PASS
# 5  NA20210222-A1D  G8T1-GH00-1046-11SA           PASS
#
#                 LogMessage        Tester        Date FailureType DeviceType
# 1  COMPLETED ON 03/23/2021  Nikky Voeuth  2021-03-23        none   Catalina
# 2  COMPLETED ON 03/23/2021  Nikky Voeuth  2021-03-23        none   Catalina
# 3  COMPLETED ON 03/23/2021  Nikky Voeuth  2021-03-23        none   Catalina
# 4  COMPLETED ON 03/23/2021  Nikky Voeuth  2021-03-23        none   Catalina
# 5  COMPLETED ON 03/23/2021  Nikky Voeuth  2021-03-23        none   Catalina
#        BatchNumber         SerialNumber FunctionalTest  \
# 1  UK20201116-A10D  G8T1-GJ00-0311-4KDB           PASS
# 2  UK20201116-A10D  G8T1-GJ00-0311-4GG8           PASS
# 3  UK20201116-A10D  G8T1-GJ00-0311-4J7S           PASS
# 4  UK20201116-A10D  G8T1-GJ00-0311-4J9K           PASS
# 5  UK20201116-A10D  G8T1-GJ00-0311-4J75           PASS
#
#                 LogMessage                 Tester        Date FailureType  \
# 1  COMPLETED ON 03/15/2021  Megan Schacht-bonneau  2021-03-15        none
# 2  COMPLETED ON 03/15/2021  Megan Schacht-bonneau  2021-03-15        none
# 3  COMPLETED ON 03/15/2021  Megan Schacht-bonneau  2021-03-15        none
# 4  COMPLETED ON 03/15/2021  Megan Schacht-bonneau  2021-03-15        none
# 5  COMPLETED ON 03/15/2021  Megan Schacht-bonneau  2021-03-15        none
#
#   DeviceType
# 1   Catalina
# 2   Catalina
# 3   Catalina
# 4   Catalina
# 5   Catalina
# ' Still need to deal with Jan, Feb, Jun, Jul'

# %%
results = [res1, res2, res3, res4, res5, res6, res7, res8]
for r in results:
    insertTable(r)
# Out:
# success!
# success!
# success!
# success!
# success!
# success!
# success!
# success!

# %%
mayFiles = [f for f in allFiles if 'May' in f and 'ipynb' not in f]
mayTables = []
for path in mayFiles:
    mayTables.append(readPath(path, 'Catalina'))
for p in mayTables:
    display(p.head())
    
for r in mayTables:
    insertTable(r)
# Out:
#       BatchNumber         SerialNumber FunctionalTest  \
# 1  NA20210412-A4D  G8T1-GH00-1095-C62C         PASSED
# 2  NA20210412-A4D  G8T1-GH00-1095-C62M         PASSED
# 3  NA20210412-A4D  G8T1-GH00-1095-C635         PASSED
# 4  NA20210412-A4D  G8T1-GH00-1095-C64W         PASSED
# 5  NA20210412-A4D  G8T1-GH00-1095-C65K         PASSED
#
#                                LogMessage        Tester        Date  \
# 1  COMPLETED AND RESET 5/11/21 (FW:10.43)  Nikky Voeuth  2021-05-11
# 2  COMPLETED AND RESET 5/11/21 (FW:10.43)  Nikky Voeuth  2021-05-11
# 3  COMPLETED AND RESET 5/11/21 (FW:10.43)  Nikky Voeuth  2021-05-11
# 4  COMPLETED AND RESET 5/11/21 (FW:10.43)  Nikky Voeuth  2021-05-11
# 5  COMPLETED AND RESET 5/11/21 (FW:10.43)  Nikky Voeuth  2021-05-11
#
#   FailureType DeviceType
# 1        none   Catalina
# 2        none   Catalina
# 3        none   Catalina
# 4        none   Catalina
# 5        none   Catalina
#       BatchNumber         SerialNumber FunctionalTest  \
# 1  NA20210419-A2D  G8T1-GH00-1095-FFNF         PASSED
# 2  NA20210419-A2D  G8T1-GH00-1095-FFNE         PASSED
# 3  NA20210419-A2D  G8T1-GH00-1095-FFNA         PASSED
# 4  NA20210419-A2D  G8T1-GH00-1095-FGNL         PASSED
# 5  NA20210419-A2D  G8T1-GH00-1095-FFN9         PASSED
#
#                    LogMessage        Tester        Date FailureType DeviceType
# 1  COMPLETED AND RESET 5/3/21  Nikky Voeuth  2021-05-03        none   Catalina
# 2  COMPLETED AND RESET 5/3/21  Nikky Voeuth  2021-05-03        none   Catalina
# 3  COMPLETED AND RESET 5/3/21  Nikky Voeuth  2021-05-03        none   Catalina
# 4  COMPLETED AND RESET 5/3/21  Nikky Voeuth  2021-05-03        none   Catalina
# 5  COMPLETED AND RESET 5/3/21  Nikky Voeuth  2021-05-03        none   Catalina
#      BatchNumber         SerialNumber FunctionalTest  \
# 1  NA20210524-3N  G8V1-GH00-1173-9TNS         PASSED
# 2  NA20210524-3N  G8V1-GH00-1173-9TP1         PASSED
# 3  NA20210524-3N  G8V1-GH00-1173-9TP3         PASSED
# 4  NA20210524-3N  G8V1-GH00-1173-9TNV         PASSED
# 5  NA20210524-3N  G8V1-GH00-1173-9TP4         PASSED
#
#                                   LogMessage                 Tester  \
# 1  COMPLETED (FW 10.43) AND RESET 05/30/2021  Megan Schacht-bonneau
# 2  COMPLETED (FW 10.43) AND RESET 05/30/2021  Megan Schacht-bonneau
# 3  COMPLETED (FW 10.43) AND RESET 05/30/2021  Megan Schacht-bonneau
# 4  COMPLETED (FW 10.43) AND RESET 05/30/2021  Megan Schacht-bonneau
# 5  COMPLETED (FW 10.43) AND RESET 05/30/2021  Megan Schacht-bonneau
#
#          Date FailureType DeviceType
# 1  2021-05-30        none   Catalina
# 2  2021-05-30        none   Catalina
# 3  2021-05-30        none   Catalina
# 4  2021-05-30        none   Catalina
# 5  2021-05-30        none   Catalina
#       BatchNumber         SerialNumber FunctionalTest  \
# 1  NA20210517-A4D  G8T1-GH00-1132-6WMK         PASSED
# 2  NA20210517-A4D  G8T1-GH00-1132-6WMS         PASSED
# 3  NA20210517-A4D  G8T1-GH00-1132-6WN1         PASSED
# 4  NA20210517-A4D  G8T1-GH00-1132-6WN5         PASSED
# 5  NA20210517-A4D  G8T1-GH00-1132-6WN0         PASSED
#
#                                LogMessage                 Tester        Date  \
# 1  COMPLETED & RESET 5/24/2021 (FW 10.43)  Megan Schacht-bonneau  2021-05-24
# 2  COMPLETED & RESET 5/24/2021 (FW 10.43)  Megan Schacht-bonneau  2021-05-24
# 3  COMPLETED & RESET 5/24/2021 (FW 10.43)  Megan Schacht-bonneau  2021-05-24
# 4  COMPLETED & RESET 5/24/2021 (FW 10.43)  Megan Schacht-bonneau  2021-05-24
# 5  COMPLETED & RESET 5/24/2021 (FW 10.43)  Megan Schacht-bonneau  2021-05-24
#
#   FailureType DeviceType
# 1        none   Catalina
# 2        none   Catalina
# 3        none   Catalina
# 4        none   Catalina
# 5        none   Catalina
# Empty DataFrame
# Columns: [BatchNumber, SerialNumber, FunctionalTest, LogMessage, Tester, Date, FailureType, DeviceType]
# Index: []
# success!
# success!
# success!
# success!
# success!

# %%
janFiles = [f for f in allFiles if 'Jan' in f and 'ipynb' not in f]
display(janFiles)
janTables = []
for path in janFiles:
    print('path', path)
    janTables.append(readPath(path, 'Catalina'))
for p in janTables:
    display(p.head())
# Out:
# ['January 2021/Catalina QC Test 01.03 01.09 2021 Restored January 08, 2021 at 08.06.49.108 AM PST.xlsx',
#  'January 2021/Catalina QC Test 01.10 01.16 2021.xlsx',
#  'January 2021/Catalina QC Test 01.24 01.30 2021.xlsx',
#  'January 2021/Catalina QC Test 01.17 01.23 2021.xlsx']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-662734776bd9> in <module>
#       3 janTables = []
#       4 for path in janFiles:
# ----> 5     janTables.append(readPath(path, 'Catalina'))
#       6 for p in janTables:
#       7     display(p.head())
#
# <ipython-input-15-ff3603413dad> in readPath(path, deviceType)
#      64     df['Tester'] = df['Tester'].apply(getTester)
#      65 #     display(df)
# ---> 66     df['Date'] = df['LogMessage'].apply(getDate)
#      67     df['FailureType'] = df['LogMessage'].apply(getFailureType)
#      68     df['DeviceType'] = deviceType
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-15-ff3603413dad> in getDate(inp)
#       9
#      10 def getDate(inp):
# ---> 11     dateVal = re.findall('[0-9][0-9]?/..?/2?0?21', inp)[0]
#      12     formatted = parser.parse(dateVal).strftime('%Y-%m-%d')
#      13     return formatted
#
# IndexError: list index out of range
